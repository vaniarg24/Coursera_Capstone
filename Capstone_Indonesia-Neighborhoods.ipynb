# %%
# @hidden_cell
# The project token is an authorization token that is used to access project resources like data sources, connections, and used by platform APIs.
from project_lib import Project
project = Project(project_id='1a3d1608-cef6-4e55-892f-e694350999b9', project_access_token='p-b1e906d1e9ca88d56cfd31d28d427663e50beb64')
pc = project.project_context

# %% [markdown]
# # The Battle of the Jakarta Neighborhoods
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Business Problem](#introduction)
# * [Data Definition](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## 1. Business Problem <a name="introduction"></a>

# %% [markdown]
# Jakarta is the capital of Indonesia, the largest city in the country, and one of the most populous urban agglomerations on earth. The population of Jakarta metropolitan area, with an area of 6,343 km2 (2,449 sq mi), was 31.6 million according to the Indonesia 2015 Inter-Census, making it the most populous region in Indonesia, as well as the second most populous urban area in the world after Tokyo. The population share of Jakarta metropolitan area to national population increased from 6.1% in 1961 to 11.26% in 2010. Today about 20% of Indonesia's urban population is concentrated in the Jakarta metropolitan area.
#
# Jakarta is now considered a global city and one of the fastest growing economies in the world. Interestingly, Jakarta reported the highest return on investment for luxury real estate in 2014 compared to any other city on earth. Considering the facts, many investors are eager to open their business in Jakarta nowadays, which makes it so important that they choose the right location according to their line of business. However, it is not easy to get the information and it also requires an analytical thinking.
#
# To address the above problem, this project will be focusing on determining the location to open new hotels in Jakarta metropolitan area, with considering the distance to city center, number of existing hotels nearby, and total of population in the area. Those factors contribute in the likelihood of optimal decision.
#
# The result will be recommendation of location candidates according to data analysis method.

# %% [markdown]
# ## 2. Data Definition<a name="data"></a>

# %% [markdown]
# There are some data needed to solve the business problem as follow.
# 1.	Center of Jakarta is defined as ‘Setiabudi’ area and its coordinate along with neighborhoods will be obtained using **Google Maps API**.
# 2. Number of existing hotels in the neighborhood. The data will be generated using **Foursquare API**.
# 3. Number of populations in the neighborhood. For this case, the data will be gathered from **Jakarta Government public data repositories** and converted to csv.
#
# All the required data will be merged into a dataset and will be used for further analysis. Data will be presented in map visualization which allows us to see the location in a quick glance.

# %% [markdown]
# ## 3. Methodology <a name="methodology"></a>

# %% [markdown]
# Below is the methodology that will be used for analysis.
#
# **1. Data Collection**
#
# We define Jakarta city center coordinates using Google Maps API, collected the location of hotels within 6 km using Foursquare and gathered population within the neighborhoods district from Jakarta public datasets.
#
# **2. Exploratory Data Analysis**
#
# Calculate the density across neighborhood using heatmaps to identify recommended area with criteria as follow:
# - Close to city center
# - Low number of hotels
# - High number of population
#
# **3. Clustering**
#
# Data analysis will be presented using k-means clustering in Folium map. The recommendation will be defined by focusing on locations close to city center (less than 2.5 km) with no hotels within radius 1 km and more than 150,000 total population.

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ### Get Neighborhood Candidates using Google Maps API
#
# Find the latitude & longitude of Jakarta city center using Google Maps API.

# %%
google_api_key = 'AIzaSyD_6MiroMbMYQvM39r1P9VEFIALuQi6Jeg'

# %%
#Function to generate coordinate using Google Maps API
import requests

def get_coordinates(api_key, address, verbose=False):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&address={}'.format(api_key, address)
        response = requests.get(url).json()
        if verbose:
            print('Google Maps API JSON result =>', response)
        results = response['results']
        geographical_data = results[0]['geometry']['location'] # get geographical coordinates
        lat = geographical_data['lat']
        lon = geographical_data['lng']
        return [lat, lon]
    except:
        return [None, None]
    
address = 'Setiabudi St, Jakarta, Indonesia'
jakarta_center = get_coordinates(google_api_key, address)
print('Coordinate of {}: {}'.format(address, jakarta_center))
# Out:
# Coordinate of Setiabudi St, Jakarta, Indonesia: [-6.2160764, 106.8300133]

# %% [markdown]
# Now we have the latitude and longitude of Jakarta center in WGS84 format, let's convert them into UTM X,Y format so we can find surrounding neighborhood area within 3 km. Once we get the neighborhood X/Y data, we need to convert them back to lat/long and show in Folium map.
#
# Our neighborhoods will be defined as circular areas with a radius of 300 meters, so our neighborhood centers will be 600 meters apart.

# %%
# Function to convert WGS84 to UTM (Cartesian)

# !pip install shapely
import shapely.geometry

# !pip install pyproj
import pyproj

import math

def lonlat_to_xy(lon, lat):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=48, datum='WGS84')
    xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
    return xy[0], xy[1]

def xy_to_lonlat(x, y):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=48, datum='WGS84')
    lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
    return lonlat[0], lonlat[1]

def calc_xy_distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return math.sqrt(dx*dx + dy*dy)
# Out:
# Requirement already satisfied: shapely in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.7.0)
# Requirement already satisfied: pyproj in /opt/conda/envs/Python36/lib/python3.6/site-packages (2.6.0)

# %%
print('Jakarta center longitude={}, latitude={}'.format(jakarta_center[1], jakarta_center[0]))
x, y = lonlat_to_xy(jakarta_center[1], jakarta_center[0])
print('Jakarta center UTM X={}, Y={}'.format(x, y))
lo, la = xy_to_lonlat(x, y)
# Out:
# Jakarta center longitude=106.8300133, latitude=-6.2160764
# Jakarta center UTM X=702479.2103012843, Y=-687440.4328693151

# %% [markdown]
# Let's create a **hexagonal grid of cells**: we offset every other row, and adjust vertical row spacing so that **every cell center is equally distant from all it's neighbors**.

# %%
jakarta_center_x, jakarta_center_y = lonlat_to_xy(jakarta_center[1], jakarta_center[0]) # City center in Cartesian coordinates

k = math.sqrt(3) / 2 # Vertical offset for hexagonal grid cells
x_min = jakarta_center_x - 3000 # offset 3 km
x_step = 600
y_min = jakarta_center_y - 3000 - (int(21/k)*k*600 - 12000)/2
y_step = 600 * k 

latitudes = []
longitudes = []
distances_from_center = []
xs = []
ys = []
for i in range(0, int(21/k)):
    y = y_min + i * y_step
    x_offset = 300 if i%2==0 else 0
    for j in range(0, 21):
        x = x_min + j * x_step + x_offset
        distance_from_center = calc_xy_distance(jakarta_center_x, jakarta_center_y, x, y)
        if (distance_from_center <= 6001):
            lon, lat = xy_to_lonlat(x, y)
            latitudes.append(lat)
            longitudes.append(lon)
            distances_from_center.append(distance_from_center)
            xs.append(x)
            ys.append(y)

print(len(latitudes), 'candidate neighborhood centers generated.')
# Out:
# 244 candidate neighborhood centers generated.

# %% [markdown]
# ### Visualize Neighborhoods using Folium Map

# %%
# !pip install folium

import folium
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.10.1)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (0.4.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)

# %%
map_jakarta = folium.Map(location=jakarta_center, zoom_start=12)
folium.Marker(jakarta_center, popup='Setiabudi (City Center)').add_to(map_jakarta)
for lat, lon in zip(latitudes, longitudes):
    folium.Marker([lat, lon]).add_to(map_jakarta)

map_jakarta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Use Google Maps API to get approximate addresses of those neighborhoods.

# %%
#Function to get address
def get_address(api_key, latitude, longitude, verbose=False):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&latlng={},{}'.format(api_key, latitude, longitude)
        response = requests.get(url).json()
        if verbose:
            print('Google Maps API JSON result =>', response)
        results = response['results']
        address = results[0]['formatted_address']
        return address
    except:
        return None

addr = get_address(google_api_key, jakarta_center[0], jakarta_center[1])
print('Reverse geocoding check')
print('-----------------------')
print('Address of [{}, {}] is: {}'.format(jakarta_center[0], jakarta_center[1], addr))
# Out:
# Reverse geocoding check
# -----------------------
# Address of [-6.2160764, 106.8300133] is: Setiabudi 2, Jl. H. R. Rasuna Said No.62, RT.6/RW.7, Kuningan, Karet Kuningan, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12920, Indonesia

# %%
print('Obtaining location addresses: ', end='')
addresses = []
for lat, lon in zip(latitudes, longitudes):
    address = get_address(google_api_key, lat, lon)
    if address is None:
        address = 'NO ADDRESS'
    address = address.replace(', Indonesia', '') # We don't need country part of address
    addresses.append(address)
    print(' .', end='')
print(' done.')
# Out:
# Obtaining location addresses:  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . done.

# %% [markdown]
# Put the data into a Pandas dataframe.

# %%
import pandas as pd

df_locations = pd.DataFrame({'Address': addresses,
                             'Latitude': latitudes,
                             'Longitude': longitudes,
                             'X': xs,
                             'Y': ys,
                             'Distance from center': distances_from_center})

df_locations.head()
# Out:
#                                              Address  Latitude   Longitude  \
# 0  5, Jl. Iskandarsyah I No.18, RT.5/RW.4, Melawa... -6.245414  106.805719
# 1  Jl. Pulo Raya III No.27, RT.1/RW.3, Petogogan,... -6.245395  106.811140
# 2  Jl. Bangka II Gg. V No.21, RT.13/RW.2, Pela Ma... -6.245376  106.816562
# 3  Jl. Pondok Karya VIII Blok I No.72, RT.11/RW.4... -6.245358  106.821983
# 4  Jl. Mampang Prapatan IV No.19, RT.2/RW.5, Mamp... -6.245339  106.827404
#
#                X              Y  Distance from center
# 0  699779.210301 -690675.815777           4213.988913
# 1  700379.210301 -690675.815777           3857.162501
# 2  700979.210301 -690675.815777           3566.188800
# 3  701579.210301 -690675.815777           3358.229080
# 4  702179.210301 -690675.815777           3249.261848

# %% [markdown]
# ### Get Venue in Neighborhood using Foursquare API
#
# Let's get hotels data in each neighborhood.

# %%
# @hidden_cell
#Connect to Foursquare API
CLIENT_ID = 'PFHHUBSQYQWBTTRZAADIDOA0N3BX2IEBOZFL33OIYJO2RNSI' # your Foursquare ID
CLIENT_SECRET = '3ZC25DGLLW5I11LZZQHKPHAF0AILLNPOJUOFQVNQTPPQ11JE' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
#Function to explore top 100 venue within radius 500 meters from provided location
LIMIT = 100

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        url   
        # make the GET request
        results = requests.get(url).json()["response"]["groups"][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood_Latitude', 
                  'Neighborhood_Longitude', 
                  'Venue', 
                  'Venue_Latitude', 
                  'Venue_Longitude', 
                  'Venue_Category']
    
    return(nearby_venues)

# %%
jakarta_venues = getNearbyVenues(names=df_locations['Address'],
                                   latitudes=df_locations['Latitude'],
                                   longitudes=df_locations['Longitude']
                                  )
# Out:
# 5, Jl. Iskandarsyah I No.18, RT.5/RW.4, Melawai, Kec. Kby. Baru, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12160
# Jl. Pulo Raya III No.27, RT.1/RW.3, Petogogan, Kec. Kby. Baru, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12170
# Jl. Bangka II Gg. V No.21, RT.13/RW.2, Pela Mampang, Kec. Mampang Prpt., Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12720
# Jl. Pondok Karya VIII Blok I No.72, RT.11/RW.4, Pela Mampang, Kec. Mampang Prpt., Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12720
# Jl. Mampang Prapatan IV No.19, RT.2/RW.5, Mampang Prpt., Kec. Mampang Prpt., Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12790
# 2, Jl. Tegal Parang Utara I No.94, RT.9/RW.5, Tegal Parang, Kec. Mampang Prpt., Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12790
# Jl. Triloka VI Blok K No.5, RT.3/RW.4, Pancoran, Kec. Pancoran, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12780
# Jl. Raya Pasar Minggu No.2 B, RT.2/RW.2, Pancoran, Kec. Pancoran, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12780
# 5, Jl. Cikoko Brt. Dalam I No.1B, RT.5/RW.4, Cikoko, Kec. Pancoran, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12770
# Jl. D No.5, RT.9/RW.2, Cikoko, Kec. Pancoran, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12770
# Jl. Cikoko Timur Raya No.64, RT.1/RW.1, Cikoko, Kec. Pancoran, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12770
# Jl. Lapang Kb. Waru No.24, RT.8/RW.2, Cawang, Kec. Kramat jati, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13630
# Jl. Madrasah X No.6, RT.1/RW.10, Cipinang Cempedak, Kec. Kramat jati, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13630
# Jl. Trunojoyo No.135, RT.6/RW.2, Melawai, Kec. Kby. Baru, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12160
# Jl. Cibulan Raya No.9, RT.15/RW.6, Petogogan, Kec. Kby. Baru, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12170
# Jl. Cisanggiri 4 No.9, RT.4/RW.4, Petogogan, Kec. Kby. Baru, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12170
# Jl. Kapt. Tendean No.11, RT.1/RW.1, Pela Mampang, Kec. Mampang Prpt., Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12720
# Jl. Kapten Tendean No.1, RT.5/RW.1, Mampang Prpt., Kec. Mampang Prpt., Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12790
# Food Court Menara Bank Mega LG floor Jalan Kapt. Tendean Kav. 12-14A, RT.2/RW.2, Mampang Prpt., Kec. Mampang Prpt., Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12790
# Jl. Gatot Subroto No.55-56, RT.9/RW.1, Menteng Dalam, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12870
# Bina Setra Lantai 1 R 114 Jl. Gatot Subroto No.71, RT.8/RW.8, Menteng Dalam, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12870
# Jl. Tebet Barat Dalam VIIC No.16, RT.6/RW.6, Tebet Bar., Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12810
# 10, Jl. Tebet Barat XII No.59, RT.10/RW.5, Tebet Bar., Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12810
# Jl. Tebet Timur Dalam VIII Q No.17, RT.4/RW.9, Tebet Tim., Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12820
# 10, Jl. Pirus No.25, RT.10/RW.11, Kp. Melayu, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13330
# Jl. Masjid No.25, RT.3/RW.7, Kp. Melayu, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13330
# Jl. Swadaya II No.52, RT.2/RW.9, Cipinang Cempedak, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13340
# Jl. Purnawarman No.99, RT.3/RW.2, Selong, Kec. Kby. Baru, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12110
# Jl. Ciranjang No.32b, RT.6/RW.3, Rw. Bar., Kec. Kby. Baru, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12180
# 1, Jl. Kebalen I No.58, RT.1/RW.5, Rw. Bar., Kec. Kby. Baru, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12180
# Jl. Kuningan Barat IV No.24C, RT.1/RW.1, Kuningan Bar., Kec. Mampang Prpt., Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12710
# Jl. H. R. Rasuna Said No.Kav 42-43, RT.8/RW.3, Kuningan, Kuningan Tim., Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12950
# Jl. Taman Patra XI No.6, RT.5/RW.4, Kuningan Tim., Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12950
# Jl. Dukuh Patra IV No.17, RT.13/RW.2, Menteng Dalam, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12870
# Jl. Masjid An Nur No.33, RT.7/RW.1, Menteng Dalam, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12870
# Jl. Tebet Bar. Dalam VIII D No.1, RT.11/RW.4, Tebet Bar., Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12810
# 6, Jl. Tebet Timur II No.8, RT.6/RW.7, Tebet Tim., Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12820
# Jl. Asem Baris Raya No.3, RT.8/RW.6, Kb. Baru, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12830
# Jl. Kb. Baru 3-9 No.31, RT.10/RW.10, Kb. Baru, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12830
# Jl. Kebon Nanas Selatan I No.19, RT.15/RW.8, Cipinang Cempedak, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13340
# Jl. Di Panjaitan No.21, RT.11/RW.2, Cipinang Cempedak, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13340
# Jl. Galuh II No.22, RT.3/RW.1, Selong, Kec. Kby. Baru, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12110
# 5, Jl. Balitung I No.9, RT.6/RW.6, Selong, Kec. Kby. Baru, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12110
# Jl. Widya Chandra VIII No.15, RT.4/RW.6, Selong, Kec. Kby. Baru, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12110
# Jl. Gatot Subroto No.Kav 16, RT.6/RW.1, Kuningan Bar., Kec. Mampang Prpt., Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12710
# Jl. Komp. Tni (Auri) No.96, RT.1/RW.3, Kuningan, Kuningan Tim., Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12950
# GD. Adhi Graha Lt. 16 Suite 1602 B, Jl. Jend. Gatot Subroto Kav.56Kuningan Timur, Setiabudi, RT.1/RW.2, Kuningan, Kuningan Tim., Setia Budi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12950
# Jl. Patra Kuningan XIII No.2, RT.6/RW.4, Kuningan Tim., Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12950
# Jl. Rasamala 8 No.26, RT.11/RW.3, Menteng Dalam, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12870
# Jl. Prof. DR. Soepomo No.44, RT.1/RW.15, Menteng Dalam, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12870
# Jl. Tebet Barat Raya No.58, RT.5/RW.7, Tebet Bar., Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12820
# Jl. Tebet Timur Dalam IV D No.10, RT.4/RW.11, Tebet Tim., Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12820
# Jl. Gudang Peluru Selatan I Blok M No.304, RT.7/RW.3, Kb. Baru, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12830
# Jl. Otista II No.2, RT.8/RW.9, Kp. Melayu, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13330
# Jl. Otto Iskandar Dinata Blok C No.22, RT.3/RW.4, Cipinang Cempedak, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13340
# STMT Trisakti 3, Cipinang Besar Sel., Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta
# Jl. Jend. Sudirman Blok LOT No.12, RT.5/RW.3, Senayan, Kec. Kby. Baru, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12190
# Jl. Scbd No.5, RT.5/RW.1, Kuningan, Senayan, Kec. Kby. Baru, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12190
# Jl. Gatot Subroto No.44, RT.5/RW.4, Karet Semanggi, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12930
# Gg. Kembang Blok Kembang No.9, RT.7/RW.1, Kuningan, Kuningan Tim., Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12950
# Gedung Kantor Taman E.3.3 Unit D, Lot. 8, 6-8, 7, Jl. Mega Kuningan Tim., RT.5/RW.2, Kuningan, Kuningan Tim., Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12950
# 17-18th Floor,, Cyber 2 Tower, Jl. H. R. Rasuna Said Blok Block X-5 No.kav 1 3, RT.7/RW.2, Kuningan, Kuningan Tim., Setia Budi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12950
# Jl. Menteng Dalam No.12, RT.10/RW.13, Menteng Dalam, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12870
# Jl. Palbatu VI No.5, RT.6/RW.11, Menteng Dalam, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12870
# Jl. Tebet Dalam I K No.9, RT.6/RW.1, Tebet Bar., Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12810
# 6, Jl. Tebet Utara III B No.11, RT.7/RW.2, Tebet Tim., Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12820
# Jl. Gudang Peluru Utara Blok C No.86, RT.1/RW.3, Kb. Baru, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12830
# Jl. Otto Iskandardinata 1A Blok a No.26, RT.5/RW.1, Kp. Melayu, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13330
# Jl. Pedati Timur Dalam No.4, RT.8/RW.9, Rw. Bunga, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13350
# Jl. Cipinang Besar No.Selatan, RT.11/RW.6, Cipinang Besar Sel., Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13410
# Jl. Antariksa III No.39, RT.1/RW.8, Cipinang Besar Sel., Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13410
# 1, RT.1/RW.3, Gelora, Tanah Abang, Central Jakarta City, Jakarta 10270
# GBK Pintu 7, Gelora, Tanahabang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta
# Komdak 1, Senayan, Kec. Kby. Baru, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta
# 8, Jl. Karet Sawah No.16, RT.8/RW.3, Kuningan, Karet Semanggi, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12930
# ITC Kuningan Lantai 1 B4 #2, Jakarta Selatan, RT.3/RW.4, Kuningan, Karet Kuningan, Setia Budi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12940
# Jl. Pedurenan Mesjid 1 No.73, RT.5/RW.4, Kuningan, Karet Kuningan, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12940
# Jl. H. Achmad Bakrie Bar. No.2, RT.2/RW.5, Kuningan, Karet Kuningan, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12940
# Jl. Menteng Pulo II No.12, RT.1/RW.12, Menteng Dalam, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12960
# Jl. Menteng Pulo No.21, RT.4/RW.5, Menteng Dalam, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12960
# Jl. Keselamatan No.1 B, RT.11/RW.2, Manggarai Sel., Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12860
# Jl. Bukit Duri Selatan No.24, RT.2/RW.7, Bukit Duri, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12840
# Gg. H. Abu No.9, RT.10/RW.10, Bukit Duri, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12840
# Jl. Jatinegara Timur No.72, RT.6/RW.3, Bali Mester, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13310
# Jl. DI. Panjaitan No.13, RT.12/RW.5, Rw. Bunga, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13350
# Gg. Prumpung Sawah II No.24, RT.11/RW.4, Cipinang Besar Utara, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13410
# Unnamed Road, RT.1/RW.3, Gelora, Tanahabang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10270
# Jl. Bendungan Walahar No.52A, RT.5/RW.2, Bend. Hilir, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10210
# Jl. Jend. Sudirman No.Kav. 47-48, RT.5/RW.4, Karet Semanggi, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12930
# Jl. K. Royani No.35, RT.7/RW.11, Kuningan, Karet Kuningan, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12940
# Jl. H. Ilyas No.17, RT.20/RW.2, Kuningan, Karet Kuningan, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12940
# Jl. Menteng Atas Bar. No.11, RT.2/RW.5, Karet Kuningan, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12940
# Jl. Menteng Atas Barat V No.13, RT.1/RW.4, Menteng Atas, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12960
# Jl. Batu Raya No.17, RT.3/RW.7, Menteng Atas, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12960
# Gg. Rusa 8 No.10, RT.10/RW.8, Manggarai Sel., Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12860
# 4, Jl. Bukit Duri Barat No.237, RT.4/RW.3, Manggarai, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12840
# Jl. Taman Bukit Duri No.6, RT.2/RW.12, Bukit Duri, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12840
# Pasar Selatan No.7, RT.7/RW.4, Bali Mester, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13310
# Jl. Bekasi Timur IX No.3b, RT.6/RW.3, Rw. Bunga, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13350
# Jl. Bekasi Timur IV No.23, RT.3/RW.9, Cipinang Besar Utara, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13410
# Jl. Swadaya No.3, RT.15/RW.11, Cipinang Besar Utara, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13410
# Jl. Gerbang Pemuda No.3, RT.1/RW.3, Gelora, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10270
# Jl. Farmasi No.17, RT.4/RW.3, Bend. Hilir, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10210
# Jl. Karet Ps. Baru Barat No.7, RT.9/RW.2, Karet Tengsin, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10250
# Jl. Jend. Sudirman No.Kav.18-20, RT.10/RW.11, Karet Tengsin, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10250
# 2, Jl. Teladan No.14, RT.2/RW.1, Kuningan, Karet, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12920
# Jl. H. R. Rasuna Said No.8, RT.10/RW.7, Kuningan, Karet, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12920
# Jl. Madiun No.8, RT.7/RW.1, Menteng Atas, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12960
# Jl. Menteng Karang No.2, RT.14/RW.6, Ps. Manggis, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12970
# Jl. Bhakti 1 No.51, RT.3/RW.4, Manggarai, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12850
# Jl. Manggarai Utara 1 No.12, RT.7/RW.1, Manggarai, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12850
# Jl. Manggarai Utara 2 No.4, RT.9/RW.1, Manggarai, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12850
# Jl. Urip Sumoharjo No.15A, RT.11/RW.6, Bali Mester, Kecamatan Jatinegara, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13310
# Jl. Pisangan Baru III No.220, RT.9/RW.7, Pisangan Baru, Kec. Matraman, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13110
# Jl. Pisangan Baru Timur VIII No.6, RT.6/RW.15, Pisangan Baru, Kec. Matraman, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13110
# Jl. Pisangan Lama III No.182, RT.4/RW.8, Pisangan Tim., Kec. Pulo Gadung, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13230
# Jl. Danau Limboto No.1, RT.11/RW.5, Bend. Hilir, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10210
# 11, Jl. Bendungan Hilir No.128, RT.13/RW.3, Bend. Hilir, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10210
# TPU Karet Pasar Baru, Karet Tengsin, Tanahabang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta
# Jl. Jend. Sudirman No.76, RT.3/RW.3, Kuningan, Setia Budi, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 10250
# Jl. Setia Budi Tengah No.30, RT.5/RW.1, Kuningan, Setia Budi, Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12910
# Namarina, Guntur, Setia Budi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta
# JL. Guntur, 55, RT.11/RW.4, Ps. Manggis, Setia Budi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12970
# No.39-, Jl. Menteng Tenggulun No.40, RT.9/RW.10, Menteng, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10310
# Jl. Manggarai Utara 1, Manggarai, Kec. Tebet, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta
# Jl. Kesatrian IX No.31, RT.28/RW.3, Kb. Manggis, Kec. Matraman, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13150
# 6, Jl. Matraman Raya No.125, RT.19/RW.9, Palmeriam, Kec. Matraman, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13140
# Jl. Kayu Manis IX No.28A, RT.13/RW.8, Kayu Manis, Kec. Matraman, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13130
# Jl. Klp. Tinggi No.12, RT.9/RW.8, Utan Kayu Sel., Kec. Matraman, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13120
# Jl. Biduri Bulan No.13, RT.4/RW.4, Pisangan Tim., Kec. Pulo Gadung, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13230
# Jl. Gading Raya No.44, RT.3/RW.10, Pisangan Tim., Kec. Pulo Gadung, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13230
# Jl. Pejompongan Raya No.24, Bend. Hilir, Tanahabang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10210
# 10, Jl. Pam Baru VI No.17, RT.10/RW.6, Bend. Hilir, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10210
# Unnamed Road, Karet Tengsin, Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10250
# Pgmta 2 lantai 1 blok b no.201, RT.10/RW.9, Karet Tengsin, Tanahabang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10250
# Sudirman Station, 10, Jl. Kendal No.24, RW.6, Dukuh Atas, Menteng, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10310
# Jl. Cimahi No.18, RT.5/RW.4, Menteng, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10310
# 1, Jl. Tulung Agung No.16, RT.1/RW.4, Menteng, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10310
# Jl. Sukabumi No.3, RT.4/RW.7, Menteng, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10310
# Jl. Proklamasi No.56, RT.10/RW.2, Pegangsaan, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10320
# Jl. Matraman Dalam I No.1, RT.3/RW.8, Pegangsaan, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10320
# Tegalan, RT.5/RW.4, Palmeriam, Kec. Matraman, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13150
# Jl. Kapuk 1 No.7, RT.13/RW.5, Kayu Manis, Kec. Matraman, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13130
# Jalan Kebon Kelapa No.16, RT.12/RW.12, Utan Kayu Sel., Kec. Matraman, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13120
# Jl. Jend. Ahmad Yani No.65, RT.6/RW.5, Utan Kayu Sel., Kec. Cemp. Putih, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13120
# Jl. Bujana Tirta 4 No.3, RT.2/RW.15, Pisangan Tim., Kec. Pulo Gadung, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13230
# Jl. Petamburan 5 No.8, RT.4/RW.8, Petamburan, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10260
# 15, Jl. Tenaga Listrik No.15, RT.15/RW.16, Kb. Melati, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10230
# Pasar Tanah Abang Lantai 2 Blok F Los Bks No 29, RT.7/RW.6, Kb. Melati, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10230
# Jl. Baturaja No.17, RT.1/RW.20, Kb. Melati, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10230
# Jl. Panarukan No.13, RT.2/RW.5, Menteng, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10310
# Jl. Taman Suropati No.5, RT.5/RW.5, Menteng, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10310
# Jl. Cilacap No.4, RT.11/RW.5, Menteng, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10310
# 10, Jl. Taman Kimia No.8, RT.10/RW.1, Pegangsaan, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10320
# Kenari, Senen, RT.3/RW.6, Kenari, Kec. Senen, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10430
# Jl. Murtado 14 No.103, RT.5/RW.6, Paseban, Kec. Senen, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10440
# Jl. Kayu Manis II No.18 A, RT.8/RW.2, Kayu Manis, Kec. Matraman, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13130
# Jl. Raya Utan Kayu No.34, RT.4/RW.7, Utan Kayu Utara, Kec. Matraman, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13120
# Gg. Paseraman No.19, RT.8/RW.10, Utan Kayu Utara, Kec. Matraman, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13120
# Jl Rawamangun Muka Barat RT 009%2F13 Jati Pulo Gadung Jakarta Timur DKI Jakarta, RT.10/RW.13, Rawamangun, Kec. Pulo Gadung, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13220
# Jl. Ks. Tubun III Blok GA No.6, RT.13/RW.1, Slipi, Kec. Palmerah, Kota Jakarta Barat, Daerah Khusus Ibukota Jakarta 11410
# Jl. Paksi No.23, RT.5/RW.3, Petamburan, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10260
# 11, Jl. Sabeni Raya No.11, RT.11/RW.12, Kb. Melati, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10230
# 10, Jl. Kb. Kacang XXXV No.16, RT.10/RW.4, Kb. Kacang, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10240
# Jl. H. Agus Salim No.110, RT.2/RW.5, Gondangdia, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10350
# Jl. Tanjung 13 Gondangdia Menteng Jakarta Pusat DKI Jakarta, RT.7/RW.1, Gondangdia, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10350
# Jl. Sawo No.38, RT.4/RW.2, Gondangdia, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10350
# Jl. Cimandiri No.1, RT.6/RW.4, Cikini, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10330
# No, Jl. Kenari 2 No.12A, RT.3/RW.3, Kenari, Kec. Senen, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10430
# 1, Jl. Salemba Tengah No.20b, RT.1/RW.4, Paseban, Kec. Senen, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10440
# Jl. Rawamangun No.9, RT.12/RW.1, Rawasari, Kec. Cemp. Putih, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10570
# Jl. Pramuka Sari II rah Khusus Ibukota No.48, Utan Kayu Utara, Kec. Matraman, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 10440
# Jl. Utan Kayu Raya No.48, RT.11/RW.5, Utan Kayu Utara, Kec. Matraman, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13120
# 11, Jl. Multi Karya III No.15, RT.11/RW.9, Utan Kayu Utara, Kec. Matraman, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13120
# Jl. R.Mangun Muka Raya No.4, RT.11/RW.14, Rawamangun, Kec. Pulo Gadung, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13220
# Jl. Brigjen Katamso No.18, RT.3/RW.3, Kota Bambu Sel., Kec. Palmerah, Kota Jakarta Barat, Daerah Khusus Ibukota Jakarta 11420
# Jalan Jati Baru 10 No 15 Jati Baru, Tanah Abang, Kp. Bali, Tanahabang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10260
# Jl. Kb. Kacang III No.31C Blok, RT.10/RW.6, Kb. Kacang, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10240
# LT4, Jalan Rumah Susun Jl. Kb. Kacang XI No.3, Kb. Kacang, Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10240
# Jl. Sumbawa No.29, RT.4/RW.4, Gondangdia, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10350
# Jl. Teuku Umar No.6, RT.1/RW.1, Gondangdia, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10350
# Jl. Cikini Raya No.59B, RT.4/RW.1, Cikini, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10330
# Jl. Kramat 5 No.21, RT.2/RW.1, Kenari, Kec. Senen, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10430
# Jl. Kramat Sentiong Gg. V Blok J No.82, RT.4/RW.1, Paseban, Kec. Senen, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10450
# Jl. Percetakan Negara II Makam No.1, RT.9/RW.8, Johar Baru, Kec. Johar Baru, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10560
# 23, Jl. Percetakan Negara No.23, RT.23/RW.7, Johar Baru, Kec. Johar Baru, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10560
# Jl. Sayuti No.28, RT.6/RW.6, Rawasari, Kec. Cemp. Putih, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10570
# Jl. Penerangan Sipil No.1, RT.13/RW.9, Rawasari, Kec. Cemp. Putih, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10640
# Jl. H. Ten Raya No.38, RT.1/RW.1, Rawamangun, Kec. Pulo Gadung, Kota Jakarta Timur, Daerah Khusus Ibukota Jakarta 13220
# Jl. Petung 1 No.31, RT.11/RW.5, Kota Bambu Utara, Kec. Palmerah, Kota Jakarta Barat, Daerah Khusus Ibukota Jakarta 11420
# Jl. Kota Bambu Utara 1 Blok K.6 No.9, RT.13/RW.3, Kota Bambu Utara, Kec. Palmerah, Kota Jakarta Barat, Daerah Khusus Ibukota Jakarta 11420
# Jl. Tanah Rendah II No.21, RT.12/RW.5, Kp. Bali, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10250
# Jl. Taman Kb. Sirih III No.42, RT.10/RW.10, Kp. Bali, Kecamatan Tanah Abang, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10250
# Jalan H Agus Salim Kawasan Kuliner BSM #64 Kebon Sirih Menteng, Jakarta Pusat, RT.2/RW.1, Kb. Sirih, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10340
# Jl. Kb. Sirih Tim. Dalam No.173, RT.1/RW.5, Kb. Sirih, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10340
# Jl. Menteng Raya No.58, RT.1/RW.10, Kb. Sirih, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10340
# 3, Jl. Kramat Kwitang 1H No.9, RT.3/RW.5, Kwitang, Kec. Senen, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10420
# Jl. Kramat Pulo Gg. 14 No.101D, RT.12/RW.4, Kramat, Kec. Senen, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10450
# Jl. Pulo Gundul No.201, RT.7/RW.1, Johar Baru, Kec. Johar Baru, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10540
# Jl. Percetakan Negara IIA No.16, RT.2/RW.3, Johar Baru, Kec. Johar Baru, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10560
# Jl. Mardani Raya No.32, RT.3/RW.13, Cemp. Putih Bar., Kec. Cemp. Putih, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10560
# 3, Jl. Cempaka Putih Barat 25 No.11, RT.3/RW.7, Cemp. Putih Bar., Kec. Cemp. Putih, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10520
# 8, Jl. Rawasari Timur Dalam 1 No.22, RT.8/RW.2, Cemp. Putih Tim., Kec. Cemp. Putih, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10510
# 14, Jl. Semangka Raya No.11, RT.15/RW.2, Jatipulo, Kec. Palmerah, Kota Jakarta Barat, Daerah Khusus Ibukota Jakarta 11430
# Jl. Citarum No.1, RT.17/RW.1, Cideng, Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10150
# Jl. Tanah Abang 5 No.21, RT.2/RW.2, Petojo Sel., Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10160
# Gedung Sapta Pesona, Jl. Tanah Abang Timur Dalam No.17, RT.2/RW.3, Gambir, Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10110
# Jl. Medan Merdeka Sel. No.1, RT.5/RW.2, Gambir, Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10110
# Jl. M.I. Ridwan Rais No.18, RT.7/RW.1, Gambir, Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10110
# Jl. Prapatan I No.34D, RT.4/RW.5, Senen, Kec. Senen, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10410
# Jl. Kecubung No.12, RT.4/RW.2, Kramat, Kec. Senen, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10450
# Jl. Arimbi No.23, RT.2/RW.7, Tanah Tinggi, Kec. Johar Baru, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10540
# Jl. Galur Raya No.38, RT.13/RW.2, Kp. Rw., Kec. Johar Baru, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10550
# Jl. Cempaka III No.2, RT.8/RW.2, Cemp. Putih Bar., Kec. Cemp. Putih, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10520
# 1, Jl. Cemp. Putih Bar. XI Gg. VII No.18, RT.1/RW.12, Cemp. Putih Bar., Kec. Cemp. Putih, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10520
# 12, Jl. Tomang Raya No.53, RT.12/RW.5, Tomang, Kec. Grogol petamburan, Kota Jakarta Barat, Daerah Khusus Ibukota Jakarta 11440
# Jl. Berumun No.4, RT.8/RW.3, Cideng, Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10150
# Jl. Tanah Abang II No.60, RT.1/RW.5, Petojo Sel., Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10160
# 1, Jl. Tanah Abang II No.5, RT.1/RW.8, Petojo Sel., Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10160
# Taman Air Mancur Pesona Monas, Jl. Titian Indah No.5, RT.5/RW.2, Gambir, Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10110
# Gambir 1, RT.5/RW.2, Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10110
# Jl. Abdul Rahman Saleh No.18, RT.9/RW.5, Senen, Kec. Senen, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10410
# Unnamed Road, RW.2, Senen, Kec. Senen, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10410
# Jl. Letjend Suprapto No.6A, RT.14/RW.6, Bungur, Kec. Senen, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10460
# Jl. Letjend Suprapto No.112, RT.9/RW.4, Tanah Tinggi, Kec. Johar Baru, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10540
# Jl. Rw. Tengah Gg. 6 No.15, RT.1/RW.6, Galur, Kec. Johar Baru, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10530
# Jl. Cempaka Putih Barat II E No.11A, RT.6/RW.3, Cemp. Putih Bar., Kec. Cemp. Putih, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10520
# Jl. Banjarmasin No.7, RT.10/RW.3, Cideng, Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10150
# 9, Jl. Cideng Timur No.41, RT.9/RW.6, Petojo Utara, Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10130
# 2, Jl. Suryopranoto No.63, RT.2/RW.7, Petojo Sel., Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10160
# JL. Majapahit No. 34, Blok 35 3th floor, 10160, RT.2/RW.3, Gambir, Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10160
# Jl. Veteran II No.12, RT.2/RW.3, Gambir, Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10110
# Jl. Katedral No.7, Ps. Baru, Kecamatan Sawah Besar, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10710
# Jl. Dr. Wahidin Raya, Ps. Baru, Kecamatan Sawah Besar, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10710
# Jl. Bungur Besar Raya No.9, RT.20/RW.3, Bungur, Kec. Senen, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10460
# Jl. Kalibaru Timur IV No.1, RT.7/RW.7, Bungur, Kec. Senen, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10460
# Jl. Sukamulia IV No.114, RT.8/RW.6, Harapan Mulya, Kec. Kemayoran, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10640
# JL KH H. Ashari, No 51RT 01/01, Cideng, Gambir, RT.9/RW.7, Petojo Utara, Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10130
# Jl. Gajah Mada No.2b, RT.2/RW.8, Kota Tua, Glodok, Kec. Taman Sari, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10130
# Jl. Batu Tulis VII No.39J, RT.3/RW.3, Kb. Klp., Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10120
# Jl. Ir. H. Juanda 1 No.10, RT.6/RW.4, Kota Tua, Kb. Klp., Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10120
# Pasar Baru 2, Ps. Baru, Kecamatan Sawah Besar, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta
# Jl. Bungur Besar Raya No.17E, RT.8/RW.7, Gn. Sahari Sel., Kec. Kemayoran, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10610
# Jl. Kemayoran Bar. No.44, RT.7/RW.6, Kemayoran, Kec. Kemayoran, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10620

# %%
print('{} venues were returned by Foursquare.'.format(jakarta_venues.shape[0]))
#jakarta_venues.head()
# Out:
# 6025 venues were returned by Foursquare.

# %%
#Filter datasets to only include hotels
jakarta_hotels=jakarta_venues.Venue_Category.str.contains('hotel', case=False)
jakarta_venues=jakarta_venues[jakarta_hotels]

#Rename column values to be standard term
jakarta_venues['Neighborhood'] = jakarta_venues['Neighborhood'].str.replace('Kec.','Kecamatan')
jakarta_venues['Kecamatan'] = jakarta_venues['Neighborhood'].str.extract(r'Kecamatan\s+(.*?),')

#Convert venue lat long to x y
xx, yy = lonlat_to_xy(jakarta_venues['Venue_Longitude'].values, jakarta_venues['Venue_Latitude'].values)

jakarta_venues['Venue_x'] = xx
jakarta_venues['Venue_y'] = yy

jakarta_venues.head(144)
#print('Total number of hotels nearby :', len(jakarta_venues))
# Out:
#                                            Neighborhood  \
# 0     5, Jl. Iskandarsyah I No.18, RT.5/RW.4, Melawa...
# 35    5, Jl. Iskandarsyah I No.18, RT.5/RW.4, Melawa...
# 46    5, Jl. Iskandarsyah I No.18, RT.5/RW.4, Melawa...
# 111   Jl. Raya Pasar Minggu No.2 B, RT.2/RW.2, Panco...
# 123   Jl. Raya Pasar Minggu No.2 B, RT.2/RW.2, Panco...
# 131   Jl. Raya Pasar Minggu No.2 B, RT.2/RW.2, Panco...
# 184   Jl. Madrasah X No.6, RT.1/RW.10, Cipinang Cemp...
# 188   Jl. Madrasah X No.6, RT.1/RW.10, Cipinang Cemp...
# 202   Jl. Trunojoyo No.135, RT.6/RW.2, Melawai, Keca...
# 303   Jl. Kapt. Tendean No.11, RT.1/RW.1, Pela Mampa...
# 308   Jl. Kapt. Tendean No.11, RT.1/RW.1, Pela Mampa...
# 329   Jl. Kapten Tendean No.1, RT.5/RW.1, Mampang Pr...
# 334   Jl. Kapten Tendean No.1, RT.5/RW.1, Mampang Pr...
# 349   Food Court Menara Bank Mega LG floor Jalan Kap...
# 376   Bina Setra Lantai 1 R 114 Jl. Gatot Subroto No...
# 390   Bina Setra Lantai 1 R 114 Jl. Gatot Subroto No...
# 397   Bina Setra Lantai 1 R 114 Jl. Gatot Subroto No...
# 491   Jl. Masjid No.25, RT.3/RW.7, Kp. Melayu, Kecam...
# 501   Jl. Swadaya II No.52, RT.2/RW.9, Cipinang Cemp...
# 506   Jl. Swadaya II No.52, RT.2/RW.9, Cipinang Cemp...
# 625   1, Jl. Kebalen I No.58, RT.1/RW.5, Rw. Bar., K...
# 637   1, Jl. Kebalen I No.58, RT.1/RW.5, Rw. Bar., K...
# 661   Jl. Kuningan Barat IV No.24C, RT.1/RW.1, Kunin...
# 668   Jl. Kuningan Barat IV No.24C, RT.1/RW.1, Kunin...
# 670   Jl. Kuningan Barat IV No.24C, RT.1/RW.1, Kunin...
# 678   Jl. H. R. Rasuna Said No.Kav 42-43, RT.8/RW.3,...
# 698   Jl. H. R. Rasuna Said No.Kav 42-43, RT.8/RW.3,...
# 711   Jl. Taman Patra XI No.6, RT.5/RW.4, Kuningan T...
# 732   Jl. Dukuh Patra IV No.17, RT.13/RW.2, Menteng ...
# 744   Jl. Masjid An Nur No.33, RT.7/RW.1, Menteng Da...
# ...                                                 ...
# 2923  Jl. Jend. Sudirman No.Kav.18-20, RT.10/RW.11, ...
# 2955  Jl. Jend. Sudirman No.Kav.18-20, RT.10/RW.11, ...
# 2970  Jl. H. R. Rasuna Said No.8, RT.10/RW.7, Kuning...
# 3057  Jl. Bhakti 1 No.51, RT.3/RW.4, Manggarai, Keca...
# 3089  Jl. Urip Sumoharjo No.15A, RT.11/RW.6, Bali Me...
# 3169  TPU Karet Pasar Baru, Karet Tengsin, Tanahaban...
# 3199  TPU Karet Pasar Baru, Karet Tengsin, Tanahaban...
# 3216  Jl. Jend. Sudirman No.76, RT.3/RW.3, Kuningan,...
# 3239  Jl. Jend. Sudirman No.76, RT.3/RW.3, Kuningan,...
# 3271  Jl. Jend. Sudirman No.76, RT.3/RW.3, Kuningan,...
# 3272  Jl. Jend. Sudirman No.76, RT.3/RW.3, Kuningan,...
# 3288  Jl. Setia Budi Tengah No.30, RT.5/RW.1, Kuning...
# 3304  Jl. Setia Budi Tengah No.30, RT.5/RW.1, Kuning...
# 3334  Namarina, Guntur, Setia Budi, Kota Jakarta Sel...
# 3336  Namarina, Guntur, Setia Budi, Kota Jakarta Sel...
# 3356  JL. Guntur, 55, RT.11/RW.4, Ps. Manggis, Setia...
# 3366  No.39-, Jl. Menteng Tenggulun No.40, RT.9/RW.1...
# 3481  Pgmta 2 lantai 1 blok b no.201, RT.10/RW.9, Ka...
# 3486  Pgmta 2 lantai 1 blok b no.201, RT.10/RW.9, Ka...
# 3502  Pgmta 2 lantai 1 blok b no.201, RT.10/RW.9, Ka...
# 3521  Pgmta 2 lantai 1 blok b no.201, RT.10/RW.9, Ka...
# 3522  Pgmta 2 lantai 1 blok b no.201, RT.10/RW.9, Ka...
# 3538  Sudirman Station, 10, Jl. Kendal No.24, RW.6, ...
# 3559  Jl. Cimahi No.18, RT.5/RW.4, Menteng, Kecamata...
# 3574  1, Jl. Tulung Agung No.16, RT.1/RW.4, Menteng,...
# 3658  Tegalan, RT.5/RW.4, Palmeriam, Kecamatan Matra...
# 3660  Tegalan, RT.5/RW.4, Palmeriam, Kecamatan Matra...
# 3682  Jl. Petamburan 5 No.8, RT.4/RW.8, Petamburan, ...
# 3746  Jl. Baturaja No.17, RT.1/RW.20, Kb. Melati, Ke...
# 3749  Jl. Baturaja No.17, RT.1/RW.20, Kb. Melati, Ke...
#
#       Neighborhood_Latitude  Neighborhood_Longitude  \
# 0                 -6.245414              106.805719
# 35                -6.245414              106.805719
# 46                -6.245414              106.805719
# 111               -6.245282              106.843668
# 123               -6.245282              106.843668
# 131               -6.245282              106.843668
# 184               -6.245186              106.870774
# 188               -6.245186              106.870774
# 202               -6.240725              106.802992
# 303               -6.240669              106.819256
# 308               -6.240669              106.819256
# 329               -6.240650              106.824677
# 334               -6.240650              106.824677
# 349               -6.240631              106.830098
# 376               -6.240593              106.840941
# 390               -6.240593              106.840941
# 397               -6.240593              106.840941
# 491               -6.240498              106.868046
# 501               -6.240479              106.873467
# 506               -6.240479              106.873467
# 625               -6.235980              106.816529
# 637               -6.235980              106.816529
# 661               -6.235961              106.821950
# 668               -6.235961              106.821950
# 670               -6.235961              106.821950
# 678               -6.235943              106.827371
# 698               -6.235943              106.827371
# 711               -6.235924              106.832793
# 732               -6.235905              106.838214
# 744               -6.235886              106.843635
# ...                     ...                     ...
# 2923              -6.212480              106.819159
# 2955              -6.212480              106.819159
# 2970              -6.212442              106.830001
# 3057              -6.212386              106.846263
# 3089              -6.212329              106.862526
# 3169              -6.207791              106.816432
# 3199              -6.207791              106.816432
# 3216              -6.207772              106.821853
# 3239              -6.207772              106.821853
# 3271              -6.207772              106.821853
# 3272              -6.207772              106.821853
# 3288              -6.207754              106.827274
# 3304              -6.207754              106.827274
# 3334              -6.207735              106.832695
# 3336              -6.207735              106.832695
# 3356              -6.207716              106.838116
# 3366              -6.207697              106.843537
# 3481              -6.203083              106.819127
# 3486              -6.203083              106.819127
# 3502              -6.203083              106.819127
# 3521              -6.203083              106.819127
# 3522              -6.203083              106.819127
# 3538              -6.203065              106.824547
# 3559              -6.203046              106.829968
# 3574              -6.203027              106.835389
# 3658              -6.202952              106.857072
# 3660              -6.202952              106.857072
# 3682              -6.198432              106.805559
# 3746              -6.198376              106.821821
# 3749              -6.198376              106.821821
#
#                                      Venue  Venue_Latitude  Venue_Longitude  \
# 0     Hotel GranDhika Iskandarsyah Jakarta       -6.244813       106.803989
# 35                           Hotel Ambhara       -6.243266       106.803678
# 46                       favehotel Melawai       -6.244321       106.801337
# 111                   Cipta Hotel Pancoran       -6.247249       106.843335
# 123                  Amaris Hotel Pancoran       -6.247507       106.842834
# 131                        V Hotel Jakarta       -6.241865       106.844744
# 184                      Harper MT Haryono       -6.245173       106.872283
# 188                      Hotel Ibis Cawang       -6.246892       106.872668
# 202   Hotel GranDhika Iskandarsyah Jakarta       -6.244813       106.803989
# 303                          Diradja Hotel       -6.240012       106.820329
# 308                      Hotel NEO Tendean       -6.238630       106.817319
# 329                          Diradja Hotel       -6.240012       106.820329
# 334         Amaris Hotel Tendean - Jakarta       -6.240015       106.826906
# 349         Amaris Hotel Tendean - Jakarta       -6.240015       106.826906
# 376                 Hotel Bidakara Jakarta       -6.240362       106.841613
# 390                        V Hotel Jakarta       -6.241865       106.844744
# 397           Swimming Pool Hotel bidakara       -6.236929       106.841325
# 491                          Hotel Fiducia       -6.239241       106.869301
# 501                          Hotel Fiducia       -6.239241       106.869301
# 506                             Park Hotel       -6.244074       106.875789
# 625             Four Seasons Hotel Jakarta       -6.232653       106.819441
# 637                      Hotel NEO Tendean       -6.238630       106.817319
# 661             Four Seasons Hotel Jakarta       -6.232653       106.819441
# 668                             Palm Court       -6.232399       106.819693
# 670                          Diradja Hotel       -6.240012       106.820329
# 678                     Gran Meliá Jakarta       -6.235042       106.830118
# 698         Amaris Hotel Tendean - Jakarta       -6.240015       106.826906
# 711                     Gran Meliá Jakarta       -6.235042       106.830118
# 732           Swimming Pool Hotel bidakara       -6.236929       106.841325
# 744              Hotel Amaris Supomo Tebet       -6.234850       106.844535
# ...                                    ...             ...              ...
# 2923                      Grand Sahid Jaya       -6.211169       106.819926
# 2955                       Prasada Mansion       -6.213473       106.821980
# 2970                Fraser Place Setiabudi       -6.215667       106.829450
# 3057                       Yello Manggarai       -6.210558       106.845224
# 3089                   Hotel Alia Matraman       -6.214496       106.863357
# 3169                AYANA MidPlaza Jakarta       -6.209002       106.819677
# 3199                           Bacchus Bar       -6.208765       106.820160
# 3216                AYANA MidPlaza Jakarta       -6.209002       106.819677
# 3239                           Bacchus Bar       -6.208765       106.820160
# 3271               Le Méridien Club Lounge       -6.211627       106.819967
# 3272                      Grand Sahid Jaya       -6.211169       106.819926
# 3288                 Aston Kuningan Suites       -6.208109       106.827140
# 3304                  Royal Kuningan Hotel       -6.206794       106.830196
# 3334                  D Hotel Sultan Agung       -6.205348       106.834354
# 3336                  Royal Kuningan Hotel       -6.206794       106.830196
# 3356                  D Hotel Sultan Agung       -6.205348       106.834354
# 3366                       Yello Manggarai       -6.210558       106.845224
# 3481             Shangri-La Hotel, Jakarta       -6.203055       106.819033
# 3486                              B.A.T.S.       -6.202724       106.818911
# 3502              All Season Thamrin Hotel       -6.201753       106.822490
# 3521                 Liberty Hotel Jakarta       -6.200205       106.822541
# 3522                            Studio One       -6.201580       106.820889
# 3538              All Season Thamrin Hotel       -6.201753       106.822490
# 3559                  Royal Kuningan Hotel       -6.206794       106.830196
# 3574                  D Hotel Sultan Agung       -6.205348       106.834354
# 3658                   Hotel Grand Menteng       -6.199929       106.855010
# 3660                       Hotel Balairung       -6.199861       106.854946
# 3682  Hotel Santika Premiere Slipi Jakarta       -6.198262       106.802332
# 3746     Hotel Indonesia Kempinski Jakarta       -6.195447       106.822052
# 3749             Mandarin Oriental Jakarta       -6.196107       106.823641
#
#      Venue_Category      Kecamatan        Venue_x        Venue_y
# 0             Hotel      Kby. Baru  699587.931649 -690608.756764
# 35            Hotel      Kby. Baru  699554.124192 -690437.517698
# 46            Hotel      Kby. Baru  699294.688423 -690553.296449
# 111           Hotel       Pancoran  703941.588910 -690893.251751
# 123           Hotel       Pancoran  703886.021918 -690921.551012
# 131           Hotel       Pancoran  704099.618926 -690298.267303
# 184           Hotel    Kramat jati  707146.307796 -690674.878332
# 188           Hotel    Kramat jati  707188.216735 -690865.198457
# 202           Hotel      Kby. Baru  699587.931649 -690608.756764
# 303           Hotel  Mampang Prpt.  701398.277136 -690083.978935
# 308           Hotel  Mampang Prpt.  701065.649216 -689929.926258
# 329           Hotel  Mampang Prpt.  701398.277136 -690083.978935
# 334           Hotel  Mampang Prpt.  702126.084668 -690086.864133
# 349           Hotel  Mampang Prpt.  702126.084668 -690086.864133
# 376           Hotel          Tebet  703753.717717 -690130.892309
# 390           Hotel          Tebet  704099.618926 -690298.267303
# 397           Hotel          Tebet  703723.158772 -689751.081465
# 491           Hotel            NaN  706818.562024 -690017.672822
# 501           Hotel            NaN  706818.562024 -690017.672822
# 506           Hotel            NaN  707534.757733 -690554.702199
# 625           Hotel      Kby. Baru  701302.720286 -689269.777802
# 637           Hotel      Kby. Baru  701065.649216 -689929.926258
# 661           Hotel  Mampang Prpt.  701302.720286 -689269.777802
# 668       Hotel Bar  Mampang Prpt.  701330.791086 -689241.687034
# 670           Hotel  Mampang Prpt.  701398.277136 -690083.978935
# 678           Hotel            NaN  702483.503955 -689538.008824
# 698           Hotel            NaN  702126.084668 -690086.864133
# 711           Hotel            NaN  702483.503955 -689538.008824
# 732           Hotel          Tebet  703723.158772 -689751.081465
# 744           Hotel          Tebet  704079.227560 -689522.341268
# ...             ...            ...            ...            ...
# 2923          Hotel            NaN  701364.634270 -686893.785363
# 2955          Hotel            NaN  701591.073532 -687149.432712
# 2970          Hotel            NaN  702417.020536 -687394.938192
# 3057          Hotel          Tebet  704164.898625 -686835.957862
# 3089          Hotel            NaN  706170.399436 -687278.496732
# 3169          Hotel            NaN  701337.848886 -686654.105381
# 3199      Hotel Bar            NaN  701391.409489 -686628.018975
# 3216          Hotel            NaN  701337.848886 -686654.105381
# 3239      Hotel Bar            NaN  701391.409489 -686628.018975
# 3271      Hotel Bar            NaN  701368.923872 -686944.449627
# 3272          Hotel            NaN  701364.634270 -686893.785363
# 3288          Hotel            NaN  702164.186489 -686558.194554
# 3304          Hotel            NaN  702503.022987 -686413.933287
# 3334          Hotel            NaN  702963.786577 -686255.503611
# 3336          Hotel            NaN  702503.022987 -686413.933287
# 3356          Hotel            NaN  702963.786577 -686255.503611
# 3366          Hotel        Menteng  704164.898625 -686835.957862
# 3481          Hotel            NaN  701268.876142 -685996.079099
# 3486      Hotel Bar            NaN  701255.481515 -685959.496645
# 3502          Hotel            NaN  701651.984057 -685853.456381
# 3521          Hotel            NaN  701658.228932 -685682.277188
# 3522          Hotel            NaN  701474.877641 -685833.644115
# 3538          Hotel        Menteng  701651.984057 -685853.456381
# 3559          Hotel        Menteng  702503.022987 -686413.933287
# 3574          Hotel        Menteng  702963.786577 -686255.503611
# 3658          Hotel       Matraman  705252.134241 -685664.170692
# 3660          Hotel       Matraman  705245.077002 -685656.592896
# 3682          Hotel            NaN  699422.202564 -685459.742270
# 3746          Hotel            NaN  701605.857004 -685155.793303
# 3749          Hotel            NaN  701781.501555 -685229.408404
#
# [144 rows x 10 columns]

# %% [markdown]
# #### Get population data

# %%
#Import population data
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_7e0a6b8ed76149af9b3f842747a5c013 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='JU5bdlJKhBqRKKyuZehXw5HxrUMEgZxmFn1R9Flxvbks',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_7e0a6b8ed76149af9b3f842747a5c013.get_object(Bucket='datasciencecapstoneproject-donotdelete-pr-xkcgnmdxqvslim',Key='Population_Data.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

# If you are reading an Excel file into a pandas DataFrame, replace `read_csv` by `read_excel` in the next statement.
df_data_0 = pd.read_csv(body)
df_data_0.head()
# Out:
#   Nama_Kecamatan   Pria  Wanita  Total_Population
# 0        Menteng  44475   43628             88103
# 1    Cemp. Putih  47964   47310             95274
# 2          Senen  63212   60421            123633
# 3     Taman Sari  63567   62323            125890
# 4     Johar Baru  69901   66604            136505

# %%
#Merge population data into datasets
jakarta_venues = pd.merge(jakarta_venues,
                 df_data_0,
                 left_on='Kecamatan',
                 right_on='Nama_Kecamatan',
                 how='left'
                 )
jakarta_venues.head()
# Out:
#                                         Neighborhood  Neighborhood_Latitude  \
# 0  5, Jl. Iskandarsyah I No.18, RT.5/RW.4, Melawa...              -6.245414
# 1  5, Jl. Iskandarsyah I No.18, RT.5/RW.4, Melawa...              -6.245414
# 2  5, Jl. Iskandarsyah I No.18, RT.5/RW.4, Melawa...              -6.245414
# 3  Jl. Raya Pasar Minggu No.2 B, RT.2/RW.2, Panco...              -6.245282
# 4  Jl. Raya Pasar Minggu No.2 B, RT.2/RW.2, Panco...              -6.245282
#
#    Neighborhood_Longitude                                 Venue  \
# 0              106.805719  Hotel GranDhika Iskandarsyah Jakarta
# 1              106.805719                         Hotel Ambhara
# 2              106.805719                     favehotel Melawai
# 3              106.843668                  Cipta Hotel Pancoran
# 4              106.843668                 Amaris Hotel Pancoran
#
#    Venue_Latitude  Venue_Longitude Venue_Category  Kecamatan        Venue_x  \
# 0       -6.244813       106.803989          Hotel  Kby. Baru  699587.931649
# 1       -6.243266       106.803678          Hotel  Kby. Baru  699554.124192
# 2       -6.244321       106.801337          Hotel  Kby. Baru  699294.688423
# 3       -6.247249       106.843335          Hotel   Pancoran  703941.588910
# 4       -6.247507       106.842834          Hotel   Pancoran  703886.021918
#
#          Venue_y Nama_Kecamatan     Pria   Wanita  Total_Population
# 0 -690608.756764      Kby. Baru  74982.0  73362.0          148344.0
# 1 -690437.517698      Kby. Baru  74982.0  73362.0          148344.0
# 2 -690553.296449      Kby. Baru  74982.0  73362.0          148344.0
# 3 -690893.251751       Pancoran  78803.0  76393.0          155196.0
# 4 -690921.551012       Pancoran  78803.0  76393.0          155196.0

# %%
#Data preprocessing
import numpy as np

#Create column to indicate population status
jakarta_venues['Is_PopulationHigh'] = np.where(jakarta_venues['Total_Population']>150000, True, False)

jakarta_venues.head()
# Out:
#                                         Neighborhood  Neighborhood_Latitude  \
# 0  5, Jl. Iskandarsyah I No.18, RT.5/RW.4, Melawa...              -6.245414
# 1  5, Jl. Iskandarsyah I No.18, RT.5/RW.4, Melawa...              -6.245414
# 2  5, Jl. Iskandarsyah I No.18, RT.5/RW.4, Melawa...              -6.245414
# 3  Jl. Raya Pasar Minggu No.2 B, RT.2/RW.2, Panco...              -6.245282
# 4  Jl. Raya Pasar Minggu No.2 B, RT.2/RW.2, Panco...              -6.245282
#
#    Neighborhood_Longitude                                 Venue  \
# 0              106.805719  Hotel GranDhika Iskandarsyah Jakarta
# 1              106.805719                         Hotel Ambhara
# 2              106.805719                     favehotel Melawai
# 3              106.843668                  Cipta Hotel Pancoran
# 4              106.843668                 Amaris Hotel Pancoran
#
#    Venue_Latitude  Venue_Longitude Venue_Category  Kecamatan        Venue_x  \
# 0       -6.244813       106.803989          Hotel  Kby. Baru  699587.931649
# 1       -6.243266       106.803678          Hotel  Kby. Baru  699554.124192
# 2       -6.244321       106.801337          Hotel  Kby. Baru  699294.688423
# 3       -6.247249       106.843335          Hotel   Pancoran  703941.588910
# 4       -6.247507       106.842834          Hotel   Pancoran  703886.021918
#
#          Venue_y Nama_Kecamatan     Pria   Wanita  Total_Population  \
# 0 -690608.756764      Kby. Baru  74982.0  73362.0          148344.0
# 1 -690437.517698      Kby. Baru  74982.0  73362.0          148344.0
# 2 -690553.296449      Kby. Baru  74982.0  73362.0          148344.0
# 3 -690893.251751       Pancoran  78803.0  76393.0          155196.0
# 4 -690921.551012       Pancoran  78803.0  76393.0          155196.0
#
#    Is_PopulationHigh
# 0              False
# 1              False
# 2              False
# 3               True
# 4               True

# %%
#Let's visualize nearby hotels in neighborhood using Folium map
map_jakarta = folium.Map(location=jakarta_center, zoom_start=13)
folium.Marker(jakarta_center, popup='Setiabudi (City Center)').add_to(map_jakarta)

# add markers to map
for lat, lng, venue, neighborhood in zip(jakarta_venues['Venue_Latitude'], jakarta_venues['Venue_Longitude'], jakarta_venues['Venue'], jakarta_venues['Neighborhood']):
    label = '{}'.format(venue)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        #fill_color='#green',
        fill_opacity=0.7,
        parse_html=False).add_to(map_jakarta)

map_jakarta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# By now, we already know the location of hotel in surrounding neighborhoods from Jakarta city center. We have gathered the required data and will be moving on to the analysis phase.

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# #### Exploratory Data Analysis

# %%
#Get neighborhood lat long
hotel_latlon = [[row[4], row[5]] for index, row in jakarta_venues.iterrows()]
#hotel_latlon

# %%
from folium.plugins import HeatMap

map_jakarta = folium.Map(location=jakarta_center, zoom_start=13)
#folium.TileLayer('cartodbpositron').add_to(map_jakarta) #cartodbpositron cartodbdark_matter
folium.Marker(jakarta_center).add_to(map_jakarta)
HeatMap(hotel_latlon).add_to(map_jakarta)
 
for lat, lng, venue, neighborhood, is_high in zip(jakarta_venues['Venue_Latitude'], jakarta_venues['Venue_Longitude'], jakarta_venues['Venue'], jakarta_venues['Neighborhood'], jakarta_venues['Is_PopulationHigh']):
    label = '{}'.format(venue)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='black' if is_high else 'grey',
        fill=True,
        #fill_color='#green',
        fill_opacity=0.7,
        parse_html=False).add_to(map_jakarta)

folium.Circle(jakarta_center, radius=3000, fill=False, color='white').add_to(map_jakarta)
map_jakarta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We can see the low hotel density closest to city center are around **south from Setiabudi area**. In addition to that, high population area are also being in the south. Looks promising. That being said, we can focus our area of interest to the south part. Let's move our center of interest and visualize with heatmap of hotel density and black color for higher population.

# %%
roi_x_min = jakarta_center_x - 2000
roi_y_max = jakarta_center_y + 1000

roi_center_x = roi_x_min + 2500
roi_center_y = roi_y_max - 2500
roi_center_lon, roi_center_lat = xy_to_lonlat(roi_center_x, roi_center_y)
roi_center = [roi_center_lat, roi_center_lon]

map_jakarta = folium.Map(location=roi_center, zoom_start=13)
HeatMap(hotel_latlon).add_to(map_jakarta)
folium.Marker(jakarta_center).add_to(map_jakarta)

for lat, lng, venue, neighborhood, is_high in zip(jakarta_venues['Venue_Latitude'], jakarta_venues['Venue_Longitude'], jakarta_venues['Venue'], jakarta_venues['Neighborhood'], jakarta_venues['Is_PopulationHigh']):
    label = '{}'.format(venue)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        #is_population_high = 
        color='black' if is_high else 'grey',
        fill=True,
        #fill_color='#green',
        fill_opacity=0.7,
        parse_html=False).add_to(map_jakarta)
    
folium.Circle(roi_center, radius=2500, color='white', fill=True, fill_opacity=0.4).add_to(map_jakarta)
map_jakarta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The new center of interest looks good. It covers the low density of hotels, high populated area and still close enough to the city center. Let's put this location into dataframe.

# %%
k = math.sqrt(3) / 2 # Vertical offset for hexagonal grid cells
x_step = 100
y_step = 100 * k 
roi_y_min = roi_center_y - 2500

roi_latitudes = []
roi_longitudes = []
roi_xs = []
roi_ys = []
for i in range(0, int(51/k)):
    y = roi_y_min + i * y_step
    x_offset = 50 if i%2==0 else 0
    for j in range(0, 51):
        x = roi_x_min + j * x_step + x_offset
        d = calc_xy_distance(roi_center_x, roi_center_y, x, y)
        if (d <= 2501):
            lon, lat = xy_to_lonlat(x, y)
            roi_latitudes.append(lat)
            roi_longitudes.append(lon)
            roi_xs.append(x)
            roi_ys.append(y)

print(len(roi_latitudes), 'candidate neighborhood centers generated.')
# Out:
# 2261 candidate neighborhood centers generated.

# %%
roi_hotels_counts = []

def count_hotels_nearby(x, y, hotel, radius):
    count = 0
    for h in hotel.values:
        h_x = h[8]; h_y = h[9]
        e = calc_xy_distance(x, y, h_x, h_y)
        if (e <= radius) :
            count+=1
    return count

for x, y in zip(roi_xs, roi_ys):
    count = count_hotels_nearby(x, y, jakarta_venues, radius=1000)
    roi_hotels_counts.append(count)

print('done')
# Out:
# done

# %% [markdown]
# #### Put candidate locations into dataframe

# %%
df_good_location = pd.DataFrame({'Latitude':roi_latitudes,
                                 'Longitude':roi_longitudes,
                                 'X':roi_xs,
                                 'Y':roi_ys,
                                 'Hotels_nearby':roi_hotels_counts,
                                 })

df_good_location.head()
# Out:
#    Latitude   Longitude              X              Y  Hotels_nearby
# 0 -6.252229  106.834205  702929.210301 -691440.432869              0
# 1 -6.252225  106.835108  703029.210301 -691440.432869              0
# 2 -6.251463  106.829232  702379.210301 -691353.830329              0
# 3 -6.251460  106.830136  702479.210301 -691353.830329              0
# 4 -6.251457  106.831040  702579.210301 -691353.830329              0

# %% [markdown]
# #### We want to focus on area with no hotels

# %%
df_good_candidates = df_good_location[df_good_location['Hotels_nearby']==0]
len(df_good_candidates)
# Out:
# 199

# %% [markdown]
# #### Let's visualize the good area candidates in map

# %%
good_latitudes = df_good_candidates['Latitude'].values
good_longitudes = df_good_candidates['Longitude'].values

good_locations = [[lat, lon] for lat, lon in zip(good_latitudes, good_longitudes)]

map_jakarta = folium.Map(location=roi_center, zoom_start=13)
HeatMap(hotel_latlon).add_to(map_jakarta)
folium.Circle(roi_center, radius=2500, color='white', fill=True, fill_opacity=0.6).add_to(map_jakarta)
folium.Marker(jakarta_center).add_to(map_jakarta)
for lat, lon in zip(good_latitudes, good_longitudes):
    folium.CircleMarker([lat, lon], radius=2, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_jakarta) 
map_jakarta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now we have area with no hotels nearby and should be a good candidates. Let's cluster these areas and get the center of it. We will use KMeans clustering with 5 number of clusters to be presented to the investors.

# %% [markdown]
# ## Clustering

# %%
from sklearn.cluster import KMeans

number_of_clusters = 5

good_xys = df_good_candidates[['X', 'Y']].values
kmeans = KMeans(n_clusters=number_of_clusters, random_state=0).fit(good_xys)

cluster_centers = [xy_to_lonlat(cc[0], cc[1]) for cc in kmeans.cluster_centers_]

map_jakarta = folium.Map(location=roi_center, zoom_start=13)
folium.Circle(roi_center, radius=2500, color='white', fill=True, fill_opacity=0.6).add_to(map_jakarta)
folium.Marker(jakarta_center).add_to(map_jakarta)
for lat, lon in zip(good_latitudes, good_longitudes):
    folium.CircleMarker([lat, lon], radius=2, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_jakarta) 
for lon, lat in cluster_centers:
    folium.Circle([lat, lon], radius=500, color='green', fill=True, fill_opacity=0.25).add_to(map_jakarta) 

map_jakarta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The clusters looks good. It represents the center of 5 candidates location. Finaly, let's **reverse geocode those candidate area centers to get the addresses**.

# %%
candidate_area = []

for lon, lat in cluster_centers:
    addr = get_address(google_api_key, lat, lon).replace(', Indonesia', '').replace(', Daerah Khusus Ibukota Jakarta ', '').replace('Kota Jakarta Selatan', '')
    candidate_area.append(addr)    
    x, y = lonlat_to_xy(lon, lat)
    d = calc_xy_distance(x, y, jakarta_center_x, jakarta_center_y)
    print('{}{} => {:.1f}km from Setiabudi'.format(addr, ' '*(50-len(addr)), d/1000))
# Out:
# 6, Jl. Tebet Utara III B No.15, RT.7/RW.2, Tebet Tim., Kec. Tebet, 12820 => 2.9km from Setiabudi
# Jl. Tegal Parang Selatan V No.47, RT.4/RW.7, Tegal Parang, Kec. Mampang Prpt., 12790 => 3.8km from Setiabudi
# Jl. Tebet Timur II G No.2, RT.9/RW.5, Tebet Tim., Kec. Tebet, 12820 => 3.5km from Setiabudi
# Jl. Mampang Prpt. Raya No.3a, RT.7/RW.1, Tegal Parang, Kec. Mampang Prpt., 12790 => 3.7km from Setiabudi
# 14, Jl. Barkah III No.29, RT.14/RW.2, Manggarai Sel., Kec. Tebet, 12860 => 2.4km from Setiabudi

# %% [markdown]
# #### The final visualization

# %%
map_jakarta = folium.Map(location=roi_center, zoom_start=13)
folium.Circle(jakarta_center, radius=50, color='red', fill=True, fill_color='red', fill_opacity=1).add_to(map_jakarta)
for lonlat, addr in zip(cluster_centers, candidate_area):
    folium.Marker([lonlat[1], lonlat[0]], popup=addr).add_to(map_jakarta) 
for lat, lon in zip(good_latitudes, good_longitudes):
    folium.Circle([lat, lon], radius=250, color='#0000ff00', fill=True, fill_color='#0066ff', fill_opacity=0.05).add_to(map_jakarta)
map_jakarta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# From analysis that we have done, we can see there's about 144 hotels within 3 km from Jakarta City Center (Setiabudi area) with the low density area detected in south. Additionally, high population density also mainly located in the south so we can focus our interest to the area.
#
# After shifting our focus, we filtered the location candidates to include only area with no hotels within 1 km. Those location were then clustered to create 5 zones of interest which contain greatest number of location candidates. Those are the recommended location for investors to open a new hotel. Finally, we generated the address of the zone centers using reverse geocoding to be used as markers for more detailed analysis based on other factors.
#
# Although we have with the recommendation, there are some other factors need to be considered further, such as tourist attraction, socioeconomics and government regulation.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# Problem addressed in this project is how to get the required information and do analysis for determining the best location candidates in opening new hotel by stakeholder/investors.
#
# By generating datasets and clustering the locations, we have identified 5 areas to be considered for further analysis. The recommendation can be used by investors in decision making process.
